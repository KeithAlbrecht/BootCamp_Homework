# %%
import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
   from sqlalchemy import create_engine
   engine = create_engine("sqlite:////data/HW.sql", echo=False)
   connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# ~\Anaconda\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# ~\Anaconda\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\Anaconda\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
# I don't think I understand the steps here...  
# I'm thinking that I first need to export the database that I put 
# together and loaded in Postgresql.  This is because I used the 
# Postgresql admin tool to import the .csv files and I didn't write it 
# into the .sql script.  So, the schema file from the ORM (QuickDBD) only 
# setup the tables and their connections.
# I used Postgresql admin tool to load the .csvs.
# Then I wrote sql statements to answer the questions from the HW.
# The HW.sql file will only work if the .csv's are loaded...  
# Am I thinking about this the right way?  Or are the .csv's now
# connected to the HW.sql because I already imported them?
